# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import hyperspy

# %%
#import hyperspy.api as hs

# %%
import matplotlib
matplotlib.rcParams["backend"] = "Qt4Agg"

# %%
from traits.etsconfig.api import ETSConfig
ETSConfig.toolkit = 'qt4'
# %matplotlib notebook
import hyperspy.api as hs
# Out:
# /opt/anaconda3/envs/hsenv2/lib/python3.7/site-packages/pyUSID/viz/__init__.py:18: FutureWarning: Please use sidpy.viz.plot_utils instead of pyUSID.viz.plot_utils. pyUSID.plot_utils will be removed in a future release of pyUSID
#   FutureWarning)

# %%
#import matplotlib
#matplotlib.rcParams["backend"] = "QtAgg"
#import hyperspy.api as hs

# %%
#matplotlib.use('WXAgg',warn=False, force=True)
#from matplotlib import pyplot as plt
#print "Switched to:",matplotlib.get_backend()

# %%
#from traits.etsconfig.api import ETSConfig
#ETSConfig.toolkit = 'qt4'
#import matplotlib
#gui_env = ['TKAgg','GTKAgg','Qt4Agg','WXAgg']
#for gui in gui_env:
#    try:
#        print ("testing", gui)
#        matplotlib.use(gui,warn=False, force=True)
#        from matplotlib import pyplot as plt
#        break
#    except:
#        continue
#print ("Using:",matplotlib.get_backend())

# %%
#from traits.etsconfig.api import ETSConfig
#ETSConfig.toolkit = 'qt4'
#import matplotlib
#gui_env = ['TKAgg','GTKAgg','Qt4Agg','WXAgg']
#for gui in gui_env:
#    try:
#        print ("testing", gui)
#        matplotlib.use(gui,warn=False, force=True)
#        from matplotlib import pyplot as plt
#        break
#    except:
#        continue
#print ("Using:",matplotlib.get_backend())

# %%
data_14 = np.load("sample_data_14.npy")
#s = hs.load("sample_data_14.txt")
#s = hs.load()
s = hs.signals.Signal1D(data_14[:,1])

# %%
N_ZLP = 1324992/0.025012626262626257

# %%
energy_data = data_14[:,0]
s.axes_manager[0].scale = np.diff(energy_data).mean()
s.axes_manager[0].units = 'keV'
s.axes_manager[0].offset = energy_data[0]
s.axes_manager[0].name = 'Energy'
s.axes_manager
# Out:
# <Axes manager, axes: (|1981)>
#             Name |   size |  index |  offset |   scale |  units
# ================ | ====== | ====== | ======= | ======= | ======
# ---------------- | ------ | ------ | ------- | ------- | ------
#           Energy |   1981 |        |      -4 |   0.025 |    keV

# %%
s.set_signal_type('EELS')
s.set_microscope_parameters(beam_energy=200, collection_angle=30)
eps, out = s.kramers_kronig_analysis(zlp = N_ZLP, n = 3, full_output = True)

# %%
print(out)
plt.figure()
plt.plot( np.real(eps))
plt.plot( np.imag(eps))
# Out:
# {'thickness': <BaseSignal, title:  thickness (calculated using Kramers-Kronig analysis), dimensions: (|1)>}
# <img src="data:image/png;base64,..." width="640">

# %%
eps.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
out['thickness'].data
# Out:
# array([16.87974764])

# %%
im = hs.load("/Users/isabel/Documents/Studie/MEP/CBL-ML/EELS_KK/dmfiles/h-ws2_eels-SI_003.dm4")
im
# Out:
# WARNING:hyperspy.io:`signal_type='DigiScan'` not understood. See `hs.print_known_signal_types()` for a list of known signal types, and the developer guide for details on how to add new signal_types.
# [<Signal2D, title: BF Image (SI Survey), dimensions: (|512, 512)>,
#  <Signal2D, title: EUDC-1 Image, dimensions: (|144, 131)>,
#  <EELSSpectrum, title: EELS Spectrum Image (aligned), dimensions: (144, 131|1961)>]

# %%
im[2].metadata
# Out:
# ├── Acquisition_instrument
# │   └── TEM
# │       ├── Detector
# │       │   └── EELS
# │       │       ├── aperture_size = 5.0
# │       │       ├── collection_angle = 100.0
# │       │       ├── dwell_time = 0.5
# │       │       ├── frame_number = 3
# │       │       └── spectrometer = GIF Continuum HR
# │       ├── Stage
# │       │   ├── tilt_alpha = -0.022099273279309273
# │       │   ├── tilt_beta = 0.00858665443956852
# │       │   ├── x = 0.20053170312500002
# │       │   ├── y = 0.36246387500000005
# │       │   └── z = 0.0139344541015625
# │       ├── acquisition_mode = STEM
# │       ├── beam_current = 0.0
# │       ├── beam_energy = 200.0
# │       ├── camera_length = 120.0
# │       ├── convergence_angle = 0.0
# │       ├── magnification = 120000.0
# │       └── microscope = ARM200 monochromated
# ├── General
# │   ├── date = 2020-11-18
# │   ├── original_filename = h-ws2_eels-SI_003.dm4
# │   ├── time = 10:03:08
# │   └── title = EELS Spectrum Image (aligned)
# └── Signal
#     ├── Noise_properties
#     │   └── Variance_linear_model
#     │       ├── gain_factor = 1.0
#     │       └── gain_offset = 0.0
#     ├── binned = True
#     ├── quantity = Intensity (Counts)
#     └── signal_type = EELS

# %%
im[2].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
eps, outs = im[2].kramers_kronig_analysis(zlp=1E8, n = 3, full_output = True)

# %%
eps.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
zlps = np.ones((128,94)) * 1E9
zlps[:60,:] = 1E8

# %%
im.get_dimensions_from_data
# Out:
# <bound method BaseSignal.get_dimensions_from_data of <EELSSpectrum, title: EELS Spectrum Image (aligned), dimensions: (128, 94|1981)>>

# %%
im[2].axes_manager
# Out:
# <Axes manager, axes: (144, 131|1961)>
#             Name |   size |  index |  offset |   scale |  units
# ================ | ====== | ====== | ======= | ======= | ======
#                x |    144 |      0 |      -0 |  0.0099 |     µm
#                y |    131 |      0 |      -0 |  0.0099 |     µm
# ---------------- | ------ | ------ | ------- | ------- | ------
#      Energy loss |   1961 |        |    -3.4 |   0.015 |     eV

# %%
eps2, out2 = im[2].kramers_kronig_analysis(zlp = zlps, n= 3, full_output = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-5bbbe2231269> in <module>
# ----> 1 eps2, out2 = im[2].kramers_kronig_analysis(zlp = zlps, n= 3, full_output = True)
#
# NameError: name 'zlps' is not defined

# %%
th = im[2].estimate_thickness(threshold=3.0)
# Out:
# WARNING:hyperspy._signals.eels:Computing the thickness without taking into account the effect ofthe limited collection angle, what usually leads to underestimatingthe thickness. To perform the angular corrections you must providethe density of the material.
# WARNING:hyperspy._signals.eels:Computing the relative thickness. To compute the absolute thickness provide the `mean_free_path` and/or the `density`

# %%
th.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
im_r = im.remove_background(signal_range= (-.0, 1.5))

# %%
im_r.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
im.isig[1]
# Out:
# <BaseSignal, title: EELS Spectrum Image (aligned), dimensions: (128, 94|)>

# %%
im.axes_manager.signal_axes[0].axis
# Out:
# array([-4.05411345, -4.02911345, -4.00411345, ..., 45.39588729,
#        45.42088729, 45.44588729])

# %%
im.isig[300]
# Out:
# <BaseSignal, title: EELS Spectrum Image (aligned), dimensions: (128, 94|)>

# %%
axis = im.axes_manager.signal_axes[0]
slicer = im.axes_manager._get_data_slice(
        [(axis.index_in_array, slice(None, axis.size)), ])

# %%
np.save("area03-eels-SI-aligned.npy", im.data)
np.save("area03-eels-SI-aligned_energy.npy",im.axes_manager.signal_axes[0].axis)

# %%
axis.axis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ae4170fb9fcb> in <module>
# ----> 1 axis.axis
#
# NameError: name 'axis' is not defined

# %%
((im.data[slicer]*-1)==im.data*-1).all()
# Out:
# True
